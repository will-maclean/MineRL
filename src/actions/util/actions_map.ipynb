# %% [markdown]
# ### Action Map
# A notebook that implements the functionality of mapping a dataset action to an action in our given action set

# %%
import torch
import wandb
import gym
import minerl
from collections import namedtuple

from minerl3161.agent import DQNAgent
from minerl3161.trainer import DQNTrainer
from minerl3161.hyperparameters import DQNHyperparameters
from minerl3161.wrappers import MineRLDiscreteActionWrapper, mineRLObservationSpaceWrapper

import os
from datetime import datetime
from pathlib import Path
import pickle

import gym
import minerl
import numpy as np
import pandas as pd
import tqdm
from kmodes.kprototypes import KPrototypes
from sklearn.cluster import KMeans
from minerl.data import BufferedBatchIter
from numpy import array, float32
# Out:
# /home/ayden/miniconda3/envs/minerl_env/lib/python3.8/site-packages/gym/logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))

# %%
NULL_ACTION = {
    'attack': 0,
    'back': 0,
    'camera0': 0.0,
    'camera1': 0.0,
    'craft': 'none',
    'equip': 'none',
    'forward': 0,
    'jump': 0,
    'left': 0,
    'nearbyCraft': 'none',
    'nearbySmelt': 'none',
    'place': 'none',
    'right': 0,
    'sneak': 0,
    'sprint': 0
}

NUM_EPOCHS = 2
BATCH_SIZE = 10
MAX_ACTIONS = 200

# Paths
ROOT_PATH = Path(os.getcwd()).absolute().parent.parent.parent
SRC_PATH = ROOT_PATH.joinpath('src')
DATA_PATH = ROOT_PATH.joinpath('data')
ACTIONS_PATH = SRC_PATH.joinpath('actions')

# %%
# Util functions
StringBuilder = lambda ENV_STRING: (f'MineRL{ENV_STRING}-v0', str(ACTIONS_PATH.joinpath(f'actions-{ENV_STRING}.pickle')))

def log(msg, level="INFO"):
    format_dict = {
        "SUCCESS": "\U00002705 SUCCESS",
        "ERROR": "\U0000274C ERROR"
    }

    print(f"{datetime.now()} | {format_dict.get(level, level)} | {msg}")
    
def check_download(environment):
    # Downloading environment data if it doesn't exist
    env_data_path = os.path.join(os.environ['MINERL_DATA_ROOT'], environment)
    if not os.path.exists(env_data_path):
        log(f"Downloading {environment} data...")
        os.mkdir(env_data_path)
        minerl.data.download(environment = environment)
        log(f"Downloaded", level="SUCCESS")

def batch_to_list(obj) -> list:
    """Decodes the batch of actions into a list of actions sutiable to fit into a dataframe.
    Important for kmodes/kmeans
    """
    actions = []

    for i in range(BATCH_SIZE):
        proc = {}
        for k in obj.keys():
            proc[k] =  obj[k][i]
        actions.append(proc)

    return actions

def encode_action(obj):
    """ Encodes the action dict into a format acceptable by minerl
    """
    proc = {}

    for k, v in obj.items():
        if 'camera' not in k:
            try:
                proc[k] = array(int(float(v) > BIN_PROB_THRESHOLD)) if not BIN_AS_CAT else array(int(float(v)))
            except:
                proc[k] = v
    
    proc['camera'] = array([obj.get('camera0'), obj.get('camera1')], dtype=float32)
    return proc

# %% [markdown]
# ## Setup & Choose ENV

# %%
# Initial setup
data_path = str(DATA_PATH)

if not os.path.exists(data_path):
    os.mkdir(data_path)

os.environ['MINERL_DATA_ROOT'] = data_path # Important

# %%
envs = ["Treechop", "Navigate", "ObtainIronPickaxe", "ObtainDiamond"]
ENVIRONMENT = "ObtainDiamond"

# %% [markdown]
# ### Check Download

# %%
environment, save_path = StringBuilder(ENVIRONMENT)
check_download(environment)

# %% [markdown]
# ### Extract Human data

# %%
data = minerl.data.make(environment = environment)
iterator = BufferedBatchIter(data)
i = 0
collected_actions = []
log("Collecting actions...")
for current_state, action, reward, next_state, done in iterator.buffered_batch_iter(batch_size=BATCH_SIZE, num_epochs=NUM_EPOCHS):
    collected_actions += batch_to_list(action)
    
    i += 1
    if i == MAX_ACTIONS // BATCH_SIZE:
        break
# Out:
# 2022-09-11 18:03:19.690623 | INFO | Collecting actions...
# 100%|██████████| 30624/30624 [00:01<00:00, 28244.71it/s]

# %%
collected_actions
# Out:
# [{'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([ 0.45000017, -0.2998047 ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-6.75,  2.25], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.15000153, -0.        ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 1},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0.6000023 , 0.44999695], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.14999962,  0.14990234], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 1,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 1,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.1500001, -0.2998047], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([-9.899998 , -2.8500977], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 1,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.        , -0.14990234], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 1,
#   'camera': array([-0.15000153, -0.        ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([2.699997  , 0.60009766], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([ 1.1999989, -0.       ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([-0.30000305, -0.        ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.       , -1.1999512], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([1.9500008, 1.5      ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0.15000153, 1.9500122 ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([ 0.14999998, -0.        ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 1,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.44999886,  4.9501953 ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([ 0.3000002 , -0.14990234], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([-2.1000004,  0.6000366], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 1,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 1,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.14999962, -0.14990234], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([-4.5      , -0.9000244], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([2.55     , 0.2998047], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.       , -1.5000153], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.        , -0.15002441], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([ 0.30000305, -0.15000153], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0.3000002 , 0.60009766], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 1},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 1},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-1.0499992 , -0.30004883], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.14999962, -0.        ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([ 3.8999996, -2.4000092], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.14999962, -0.        ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.29999924, -0.75      ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([ -7.65    , -18.900024], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-2.4      , -2.5500183], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([ 0.15000153, -0.        ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.        ,  0.44995117], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0.8999996 , 0.89990234], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 1,
#   'jump': 1,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.        , -0.30004883], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.45000005, -1.9499512 ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([ 0.30000305, -0.15002441], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 1},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([ 0.14999962, -0.        ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 1,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 1,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.        , -0.14990234], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([-0.       , -0.7501221], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 1,
#   'jump': 1,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 1,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-7.200001  , -0.45007324], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([ 0.5999985, -0.       ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-8.849999,  0.75    ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.30000305,  0.1499939 ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 1,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.7500076, -0.2999878], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-2.1000004, -3.0002441], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([ 0.45000076, -0.        ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.9000006, -1.0500488], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 1,
#   'camera': array([-0.8999996,  0.75     ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 1},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.14999962, -0.2998047 ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 1,
#   'jump': 0,
#   'left': 1,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.       , -0.2999878], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([-1.8000002,  5.699951 ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([-0.14999962, -0.        ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 1,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([ 0.14999962, -0.14990234], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([ 11.700001, -43.499878], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([ 2.1000004, -6.75     ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 1,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([-0.       , -0.4500122], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 1,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([7.049999 , 1.0500488], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.3000002,  1.2000732], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 1,
#   'jump': 0,
#   'left': 1,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 1,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.       , -0.6000366], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 1,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 1},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([-3.1500015, -5.699997 ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([ 0.15000153, -0.        ], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 1,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 1,
#   'camera': array([-0.        , -0.14990234], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-2.8499985, -3.2999992], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 1,
#   'back': 0,
#   'camera': array([-0.       , -0.8999977], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0},
#  {'attack': 0,
#   'back': 0,
#   'camera': array([0., 0.], dtype=float32),
#   'craft': 'none',
#   'equip': 'none',
#   'forward': 0,
#   'jump': 0,
#   'left': 0,
#   'nearbyCraft': 'none',
#   'nearbySmelt': 'none',
#   'place': 'none',
#   'right': 0,
#   'sneak': 0,
#   'sprint': 0}]

# %%
# TODO: Take one from above and map to action space.
